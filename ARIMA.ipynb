# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from pandas.plotting import autocorrelation_plot
import pandas.util.testing as tm
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from numpy import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
from math import sqrt
import warnings
warnings.filterwarnings('ignore')

# %%
# Leitura do CSV e setando como Time
df = pd.read_csv('FT02_18_19.csv',delimiter=';', parse_dates=True)
df['Time'] = pd.to_datetime(df.Time)
df = df[df['Time'].notna()]
df = df.set_index('Time')
df = df.resample("D").last()

# %%
#Separar dados de treino e teste
dias = 30
train = df.iloc[:-dias,0:1].copy()
test = df.iloc[-dias:,0:1].copy()

history = [train.iloc[i,0] for i in range(len(train))]
predictions = []

# %%
# Visualização das amostras de treino e teste
plt.figure(figsize=(18,5))
plt.title('Vazão de Gravidade')
plt.plot(train['Vazao02'], color='b')
plt.plot(test['Vazao02'], color='orange')
plt.legend(['Treino','Teste'])
plt.xlabel('Data')
plt.ylabel('m³/h')
plt.show()

# %%
#Verificando Residuais, Sazonalidade e Tendencias
result = seasonal_decompose(train, freq=30)
fig = result.plot()
fig.set_size_inches(15,6)

# %%
#Verificando atraves de Dickey Fuller a estacionariedade
X = df.values
result = adfuller(X)
print(result)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# (-6.516358527194385, 1.0689057282523643e-08, 7, 722, {'1%': -3.439439614524914, '5%': -2.865551414233055, '10%': -2.5689061365397747}, 5497.581949546244)
# ADF Statistic: -6.516359
# p-value: 0.000000
# Critical Values:
# 	1%: -3.439
# 	5%: -2.866
# 	10%: -2.569

# %%
# Análise de auto correlação dos lags anteriores
fig, ax = plt.subplots(1,2,figsize=(15,6))
plot_acf(train['Vazao02'], lags=60, zero=False, ax=ax[0]);
plot_pacf(train['Vazao02'], lags=60, zero=False, ax=ax[1]);
ax[0].legend(["Vazão_de_Gravidade"], loc="upper right")
ax[1].legend(["Vazão_de_Gravidade"], loc="upper right")
plt.show()

# %%
#Rodar o ARIMA para os dados de treino, fazer forecast para o tamanho dos dados test
for t in range(len(test)):
    model = ARIMA(history, order=(3,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test.iloc[t,0]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
test['Predict'] = predictions
# Out:
# predicted=126.469672, expected=112.300000
# predicted=121.449685, expected=119.890000
# predicted=120.333849, expected=129.610000
# predicted=124.161645, expected=118.980000
# predicted=121.350295, expected=124.100000
# predicted=122.869571, expected=113.400000
# predicted=119.510282, expected=124.130000
# predicted=120.334238, expected=120.600000
# predicted=121.124025, expected=126.240000
# predicted=122.611174, expected=111.370000
# predicted=118.766863, expected=126.410000
# predicted=121.225767, expected=118.720000
# predicted=121.007227, expected=117.100000
# predicted=118.132259, expected=111.820000
# predicted=116.334119, expected=111.450000
# predicted=113.345079, expected=112.440000
# predicted=112.707114, expected=108.700000
# predicted=110.609876, expected=117.420000
# predicted=113.373586, expected=127.380000
# predicted=119.872905, expected=123.580000
# predicted=121.865067, expected=120.330000
# predicted=121.906816, expected=125.750000
# predicted=124.125232, expected=124.390000
# predicted=124.157232, expected=110.490000
# predicted=118.044189, expected=128.970000
# predicted=122.516790, expected=124.470000
# predicted=123.851592, expected=118.710000
# predicted=120.774163, expected=110.740000
# predicted=117.495959, expected=119.660000
# predicted=117.605194, expected=121.240000

# %%
# Plotar a previsão e comparar com os testes
plt.figure(figsize=(15,6))
plt.plot(test['Vazao02'])
plt.plot(test['Predict'], color='red')
plt.title('Vazão de gravidade')
plt.legend(['Vazão de Gravidade', 'Predições'], loc="upper right")
plt.show()

# %%
# -----------------------------Função para analisar erros--------------------------------
def check_erro(orig, prev, nome_col='', nome_indice=''):
    
    mse = mean_squared_error(orig, prev)
    rmse = sqrt(mean_squared_error(orig, prev))
    mae = mean_absolute_error(orig, prev)
    mape = mean_absolute_percentage_error(orig, prev)
    
    grupo_erro = [mse, rmse, mae, mape]
    serie = pd.DataFrame(grupo_erro, index=['MSE','RMSE','MAE', 'MAPE'], columns=[nome_col])
    serie.index.name = nome_indice
    
    return serie
    
def plotar_erro(dados, figsize=(15,6)):
    
    # Criando a coluna do erro
    dados['Erro'] = dados.iloc[:,0] - dados.iloc[:,1]
    
    plt.figure(figsize=figsize)
    ax1 = plt.subplot2grid((2,2), (0,0))
    ax2 = plt.subplot2grid((2,2), (0,1))
    ax3 = plt.subplot2grid((2,2), (1,0))
    ax4 = plt.subplot2grid((2,2), (1,1))
    
    #Plotando os valores reais e previstos
    ax1.plot(dados.iloc[:,0:2])
    ax1.legend(['Real','Prev'])
    ax1.set_title('Valores Reais vs Previstos')
    
    # Erro vs Valores previstos
    ax2.scatter(dados.iloc[:,1], dados.iloc[:,2])
    ax2.set_xlabel('Valores Previstos')
    ax2.set_ylabel('Resíduo')
    ax2.set_title('Resíduo vs Valores Previstos')
    
    ## QQ Plot do erro
    sm.graphics.qqplot(dados.iloc[:,2], line='r', ax=ax3)
    
    # Gráfico de autocorrelação do Erro
    plot_acf(dados.iloc[:,2], lags=29, zero=False, ax=ax4)
    plt.tight_layout()
    plt.show()

# %%
erro_teste = check_erro(test['Vazao02'], test['Predict'], nome_col='Simples',nome_indice='Base Teste')
print('MODELO ARIMA PARA O TREINO COMPARADO NA BASE DE TESTE')

plotar_erro(test)
erro_teste
# Out:
# MODELO ARIMA PARA O TREINO COMPARADO NA BASE DE TESTE
#               Simples
# Base Teste
# MSE         49.210786
# RMSE         7.015040
# MAE          5.716709
# MAPE         0.048349

# %%
# prevendo n steps a frente
pred_treino = model_fit.predict()
pred_treino[:5]
pred_treino[0] += train.iloc[0,0]
pred_treino = np.cumsum(pred_treino)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2528/3653825711.py in <module>
#       3 pred_treino[0] += train.iloc[0,0]
#       4 pred_treino = np.cumsum(pred_treino)
# ----> 5 pred_treino.head
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
train['Pred Vazao'] = pred_treino
train.dropna(inplace=True)
train.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2528/427014145.py in <module>
# ----> 1 train['Pred Vazao'] = pred_treino
#       2 train.dropna(inplace=True)
#       3 train.head()
#
# c:\Users\Marcelo Avanzi\Documents\TCC\venv\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# c:\Users\Marcelo Avanzi\Documents\TCC\venv\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# c:\Users\Marcelo Avanzi\Documents\TCC\venv\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# -> 4504             com.require_length_match(value, self.index)
#    4505         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4506
#
# c:\Users\Marcelo Avanzi\Documents\TCC\venv\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (728) does not match length of index (700)
